# %% [markdown]
# # Визуализация. Домашняя работа

# %%
#отображение графиков в тетрадке
# %matplotlib inline
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

import pandas as pd
import plotly
import seaborn as sns

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10,5

# %%
submission = pd.read_csv("../data/NYC/sample_submission.zip")

# Player - Player's full name (first and last)
# height - Height in cm
# weight - Weight in kg
# collage - The college said player attended
# born - Birthdate of the player
# birth_city - City where the player was born.
# birth_state - State where the player was born
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625134 entries, 0 to 625133
# Data columns (total 2 columns):
# id               625134 non-null object
# trip_duration    625134 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 9.5+ MB

# %%
seasons = pd.read_csv("../data/NBA/Seasons_Stats.csv")
seasons[['Year','Tm', 'PF', 'Player', 'Year']].head()

# Year - Season
# Player - name
# Pos - Position
# Age - Age
# Tm - Team
# G - Games
# GS - Games Started
# MP - Minutes Played
# PER - Player Efficiency Rating
# TS% - True Shooting %
# 3PAr - 3-Point Attempt Rate
# FTr - Free Throw Rate
# ORB% - Offensive Rebound Percentage
# DRB% - Defensive Rebound Percentage
# TRB% - Total Rebound Percentage
# AST% - Assist Percentage
# STL% - Steal Percentage
# BLK% - Block Percentage
# TOV% - Turnover Percentage
# USG% - Usage Percentage
# blanl - 
# OWS - Offensive Win Shares
# DWS - Defensive Win Shares
# WS - Win Shares
# WS/48 - Win Shares Per 48 Minutes
# blank2 - 
# OBPM - Offensive Box Plus/Minus
# DBPM - Defensive Box Plus/Minus
# BPM - Box Plus/Minus
# VORP - Value Over Replacement
# FG - Field Goals
# FGA - Field Goal Attempts
# FG% - Field Goal Percentage
# 3P - 3-Point Field Goals
# 3PA - 3-Point Field Goal Attempts
# 3P% - 3-Point Field Goal Percentage
# 2P - 2-Point Field Goals
# 2PA - 2-Point Field Goal Attempts
# 2P% - 2-Point Field Goal Percentage
# eFG% - Effective Field Goal Percentage
# FT - Free Throws
# FTA - Free Throw Attempts
# FT% - Free Throw Percentage
# ORB - Offensive Rebounds
# DRB - Defensive Rebounds
# TRB - Total Rebounds
# AST - Assists
# STL - Steals
# BLK - Blocks
# TOV - Turnovers
# PF - Personal Fouls
# PTS - Points
# Out:
#      Year   Tm     PF           Player    Year
# 0  1950.0  FTW  217.0  Curly Armstrong  1950.0
# 1  1950.0  INO   99.0     Cliff Barker  1950.0
# 2  1950.0  CHS  192.0    Leo Barnhorst  1950.0
# 3  1950.0  TOT   29.0       Ed Bartels  1950.0
# 4  1950.0  DNN   27.0       Ed Bartels  1950.0

# %%
player = pd.read_csv("../data/NBA/player_data.csv")
player.head()

# name - player name
# year_start
# year_end
# position
# height
# weight
# birth_date
# college
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
season_ = seasons[['Player', 'Age', 'PTS', 'MP', 'G', 'GS', 'Pos', 'STL%', 'Year']]

# %%
seasin_info[["ORB", "DRB" , 'TRB', 'AST', 'STL', 'BLK',  'TOV',  'PF', 'PTS']].plot()

# %%
# Использование seaborn. Корреляция признаков
# %config InlineBackend.figure_format = 'png' 
data = seasons[(seasons['Year']==2017)].groupby('Player').median().corr()
sns_corr = sns.heatmap(data)
#Картинка должна сохраниться в текущей папке
sns_corr.figure.savefig('heatmap.png')

# %%
# Топ игроков по очкам
top_players_df = seasons[(seasons['Year']==2017)].groupby('Player').sum()
    
mean_pts = top_players_df['PTS']/top_players_df['G']
mean_pts.sort_values(ascending=Fa)
# Out:
# Player
# A.J. Hammons            2.181818
# Aaron Brooks            4.953846
# Aaron Gordon           12.737500
# Aaron Harrison          0.200000
# Adreian Payne           3.500000
# Al Horford             14.000000
# Al Jefferson            8.106061
# Al-Farouq Aminu         8.721311
# Alan Anderson           2.866667
# Alan Williams           7.361702
# Alec Burks              6.738095
# Alex Abrines            5.970588
# Alex Len                7.961039
# Alex Poythress         10.666667
# Alexis Ajinca           5.307692
# Allen Crabbe           10.696203
# Alonzo Gee              0.846154
# Amir Johnson            6.500000
# Anderson Varejao        1.285714
# Andre Drummond         13.641975
# Andre Iguodala          7.552632
# Andre Roberson          6.607595
# Andrew Bogut            2.925926
# Andrew Harrison         5.902778
# Andrew Nicholson        2.631579
# Andrew Wiggins         23.573171
# Anthony Bennett         5.000000
# Anthony Brown           3.909091
# Anthony Davis          27.986667
# Anthony Morrow          5.530612
#                          ...
# Trey Burke              5.000000
# Trey Lyles              6.197183
# Tristan Thompson        8.076923
# Troy Daniels            8.223881
# Troy Williams           6.166667
# Ty Lawson               9.869565
# Tyler Ennis             4.301887
# Tyler Johnson          13.726027
# Tyler Ulis              7.278689
# Tyler Zeller            3.490196
# Tyreke Evans           10.275000
# Tyson Chandler          8.446809
# Tyus Jones              3.483333
# Udonis Haslem           1.823529
# Victor Oladipo         15.925373
# Vince Carter            8.027397
# Wade Baldwin            3.212121
# Wayne Ellington        10.451613
# Wayne Selden            5.071429
# Wesley Johnson          2.735294
# Wesley Matthews        13.506849
# Will Barton            13.666667
# Willie Cauley-Stein     8.146667
# Willie Reed             5.267606
# Willy Hernangomez       8.152778
# Wilson Chandler        15.732394
# Yogi Ferrell           10.043478
# Zach LaVine            18.914894
# Zach Randolph          14.082192
# Zaza Pachulia           6.085714
# Length: 486, dtype: float64
